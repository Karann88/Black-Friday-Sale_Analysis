# %%
# %pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
df1=df.copy()

# %%
df1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df1.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
df1["User_ID"]=df1["User_ID"].astype(str)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  object
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(4), object(6)
# ...

# %%
df1["Gender"]=df1["Gender"].replace({"F":0,"M":1})
df1.head()
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_26240\3466456711.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1["Gender"]=df1["Gender"].replace({"F":0,"M":1})
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  object
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  int64
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df1.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df1["Product_Category_2"]=df1["Product_Category_2"].fillna(np.mean(df1["Product_Category_2"]))
df1["Product_Category_3"]=df1["Product_Category_3"].fillna(np.mean(df1["Product_Category_3"]))

# %%
df1.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
sns.heatmap(df1.iloc[:,7:].corr(),cmap="Blues")
# Out:
# <Axes: >

# %%
df1["User_ID"].nunique()
# Out:
# 5891

# %%
df1["Product_ID"].nunique()
# Out:
# 3623

# %%
df1["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df1["Age"].nunique()
# Out:
# 7

# %%
df1["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df1["Occupation"].nunique()
# Out:
# 21

# %%
df1["City_Category"].nunique()
# Out:
# 3

# %%
df1["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
print(df1["Product_Category_1"].nunique())
# Out:
# 18

# %%
print(df1["Purchase"].sum())
# Out:
# 5017668378

# %%
for column in df.columns:
    print(df[column].nunique(),"\t: ",column)
# Out:
# 5891 	:  User_ID
# 3623 	:  Product_ID
# 2 	:  Gender
# 7 	:  Age
# 21 	:  Occupation
# 3 	:  City_Category
# 5 	:  Stay_In_Current_City_Years
# 2 	:  Marital_Status
# 18 	:  Product_Category_1
# 17 	:  Product_Category_2
# 15 	:  Product_Category_3
# 17959 	:  Purchase

# %%
print("The total number of male who did purchase in Sale are: ",len(df[df["Gender"]=="M"]))
# Out:
# The total number of male who did purchase in Sale are:  405380

# %%
print("The total number of female who did purchase in Sale are: ",len(df[df["Gender"]=="F"]))
# Out:
# The total number of female who did purchase in Sale are:  132197

# %%
data=pd.DataFrame({"Ratio":[len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])]},index=["Male","Female"])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y="Ratio",figsize=(4,4),autopct="%.1f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
df1.groupby("Gender").size().plot(kind="pie",autopct="%.1f",title="Gender ratio",figsize=(4,4))
# Out:
# <Axes: title={'center': 'Gender ratio'}>

# %%
df1.groupby("Gender").size().plot(kind="bar",figsize=(4,4))
# Out:
# <Axes: xlabel='Gender'>

# %%
# df1.groupby("Gender").sum()["Purchase"].plot(kind="pie",autopct="%.1f")

# %%
# df1.groupby("Gender").mean()["Purchase"].plot(kind="pie",autopct="%.1f")

# %%
df1.groupby("Age").size().plot(kind="bar",title="Purchase distribution by Age")
# Out:
# <Axes: title={'center': 'Purchase distribution by Age'}, xlabel='Age'>

# %% [markdown]
# No of unique products which are purchased in a group

# %%
lst=[]
for i in df1["Age"].unique():
    lst.append([i,df1[df1["Age"]==i]["Product_ID"].nunique()])

data=pd.DataFrame(lst,columns=["Age","Products"])
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot.bar(x="Age")
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df1.groupby("Age").sum()["Purchase"].plot(kind="bar",title="Amount spend by Age")
# Out:
# <Axes: title={'center': 'Amount spend by Age'}, xlabel='Age'>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  object
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  int64
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          537577 non-null  float64
#  10  Product_Category_3          537577 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df1.groupby("Age")["Purchase"].mean().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df1.groupby("Marital_Status").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
df1.groupby("Gender").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
sns.set(rc={"figure.figsize":(10,6)})
sns.countplot(x="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={"figure.figsize":(10,6)})
sns.countplot(x="Gender",hue="Age",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={"figure.figsize":(10,6)})
sns.countplot(x="Gender",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Age",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=df["City_Category"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x="City_Category",hue="Age",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x="Age",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Gender",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby("City_Category").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("City_Category")["Purchase"].mean().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: ylabel='Purchase'>
